# %%
from obspy.clients.fdsn import Client
client = Client("iris")
print(client)
# Out:
# FDSN Webservice Client (base url: http://service.iris.edu)
# Available Services: 'dataselect' (v1.1.5), 'event' (v1.1.7), 'station' (v1.1.25), 'available_event_catalogs', 'available_event_contributors'
#
# Use e.g. client.help('dataselect') for the
# parameter description of the individual services
# or client.help() for parameter description of
# all webservices.

# %%
client.services
# Out:
# {'available_event_catalogs': {'GCMT', 'ISC', 'NEIC PDE'},
#  'available_event_contributors': {'A',
#   'AEI',
#   'AEIC',
#   'AG',
#   'AGS',
#   'ALG',
#   'ARO',
#   'ATH',
#   'AUST',
#   'B',
#   'BDF',
#   'BEO',
#   'BER',
#   'BGS',
#   'BHL',
#   'BJI',
#   'BLA',
#   'BOU',
#   'BRK',
#   'BSE',
#   'BUC',
#   'BUT',
#   'BYKL',
#   'C',
#   'CAR',
#   'CASC',
#   'CERI',
#   'CI',
#   'CLE',
#   'CNRM',
#   'CSC',
#   'CSEM',
#   'CSS',
#   'D',
#   'DBN',
#   'DDA',
#   'DHMR',
#   'DJA',
#   'DMN',
#   'DNK',
#   'DOE',
#   'E',
#   'ECX',
#   'EPT',
#   'EXP',
#   'FBB',
#   'FDF',
#   'G',
#   'GCMT',
#   'GEN',
#   'GFU',
#   'GII',
#   'GL',
#   'GOM',
#   'GRF',
#   'GUC',
#   'H',
#   'HDC',
#   'HEL',
#   'HLW',
#   'HOJ',
#   'HON',
#   'HV',
#   'HVO',
#   'I',
#   'INDR',
#   'INMG',
#   'IRSA',
#   'ISC',
#   'ISK',
#   'J',
#   'JMA',
#   'JSN',
#   'L',
#   'LAK',
#   'LD',
#   'LDG',
#   'LIM',
#   'LJU',
#   'M',
#   'MAC',
#   'MACR',
#   'MB',
# ...
